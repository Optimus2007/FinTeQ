# %% [markdown]
# # Level-1 Step-by-Step Notebook
# Run this notebook from top to bottom. Each section maps to your Level-1 files in order: A, B, C, D.

# %% [markdown]
# ## 1) Install Requirements

# %%
# !pip install perceval-quandela
# !pip install merlinquantum
# !pip install perceval-quandela
# !pip install torch torchvision

import merlin
import perceval as pcvl
import torch
print("All good!")

# %% [markdown]
# ## 2) Setup Paths

# %%
from pathlib import Path
import runpy

ROOT = Path('..').resolve()
L1_DIR = ROOT / 'src' / 'level1_primary'

print('Repo root:', ROOT)
print('Level-1 dir:', L1_DIR)
print('Files present:', [p.name for p in sorted(L1_DIR.glob('level1_*.py'))])

# %% [markdown]
# ## 3) Run A

# %%
runpy.run_path(str(L1_DIR / 'level1_a.py'), run_name='__main__')

# %% [markdown]
# ## 4) Run B

# %%
runpy.run_path(str(L1_DIR / 'level1_b.py'), run_name='__main__')

# %% [markdown]
# ## 5) Run C

# %%
runpy.run_path(str(L1_DIR / 'level1_c.py'), run_name='__main__')

# %% [markdown]
# ## 6) Run D

# %%
runpy.run_path(str(L1_DIR / 'level1_d.py'), run_name='__main__')
