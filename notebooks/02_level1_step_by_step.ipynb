# %% [markdown]
# # Level-1 Step-by-Step Notebook
# Run this notebook from top to bottom. The Level-1 files run in order:
# 1) `level1_01_quantum_kernel_submission.py`
# 2) `level1_02_baseline_validation.py`

# %% [markdown]
# ## 1) Install Requirements

# %%
# !pip install perceval-quandela
# !pip install merlinquantum
# !pip install perceval-quandela
# !pip install torch torchvision

import merlin
import perceval as pcvl
import torch
print("All good!")

# %% [markdown]
# ## 2) Setup Paths

# %%
from pathlib import Path
import runpy

ROOT = Path('..').resolve()
L1_DIR = ROOT / 'src' / 'level1_primary'

print('Repo root:', ROOT)
print('Level-1 dir:', L1_DIR)
print('Files present:', [p.name for p in sorted(L1_DIR.glob('level1_*.py'))])

# %% [markdown]
# ## 3) Run Level 1 — Part 1

# %%
runpy.run_path(str(L1_DIR / 'level1_01_quantum_kernel_submission.py'), run_name='__main__')

# %% [markdown]
# ## 4) Run Level 1 — Part 2

# %%
runpy.run_path(str(L1_DIR / 'level1_02_baseline_validation.py'), run_name='__main__')
