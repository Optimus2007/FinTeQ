# %% [markdown]
# # 03 Quantum Model
# Run final Level-2 quantum-boosted hybrid model.

# %%
import sys
from pathlib import Path

project_root = Path('..').resolve()
sys.path.append(str(project_root / 'src'))

from level2_secondary.qml_extension import run_level2_qml_extension

report = run_level2_qml_extension(
    template_path=str(project_root / 'inputs' / 'test_template.xlsx'),
    output_xlsx=str(project_root / 'results' / 'test_template_filled_hybrid.xlsx'),
    output_report=str(project_root / 'results' / 'level2_validation_report.json'),
    min_quantum_weight=0.50,
    cv_repeats=3,
)
report['hybrid_params']
