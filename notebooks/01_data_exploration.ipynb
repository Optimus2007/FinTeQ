# %% [markdown]
# # 01 Data Exploration
# Basic loading and inspection for Level-2 training data.

# %%
from datasets import load_dataset
import pandas as pd

ds = load_dataset('Quandela/Challenge_Swaptions', data_files='level-2_Missing_data_prediction/train_level2.csv', split='train')
df = ds.to_pandas()
df.head()
